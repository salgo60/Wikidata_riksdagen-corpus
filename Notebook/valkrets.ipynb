# %% [markdown]
# ### Get valkrets from Riksdagens öppna data
# * see [#148](https://github.com/salgo60/Wikidata_riksdagen-corpus/issues/148)
# * this [notebook](https://github.com/salgo60/Wikidata_riksdagen-corpus/blob/main/Notebook/valkrets.ipynb)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2023-06-01 16:55:53.485365

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
url ="http://data.riksdagen.se/personlista/?rdlstatus=samtliga&utformat=json&termlista="

r = http.request('GET', url)
data = json.loads(r.data)
dftot = pd.DataFrame(data["personlista"]["person"])
dftot.head()
# Out:
#                             hangar_guid                              sourceid  \
# 0  fb76d4e2-c24f-4bbc-9ee3-6abe12a7a520  e9375099-ca5f-4aac-a0ab-de8e3ed1ee99
# 1  9b9ed4ec-b46b-4c1c-85ce-0f8edda77518  b0cce726-5e23-4d21-a609-95071f8820f0
# 2  37bd5192-5966-40f7-96f2-47e168c8b536  b4bf17ad-b37d-44ee-bf62-eaf4942a2a43
# 3  e648b0e4-769f-419a-b11e-9283749655a4  ed3399e1-7bce-4ea4-baf6-587f722710f5
# 4  2df03cc0-403c-4940-b30e-8633b7cb7801  3139e412-6409-4376-9e02-674a4e4a2de9
#
#    intressent_id hangar_id fodd_ar     kon efternamn tilltalsnamn  \
# 0  0925652297119   2369366    1967     man   Ramhorn          Per
# 1  0512510717328   5003992    1987  kvinna     Busch         Ebba
# 2  0383111552218   2369385    1964     man  Sjöstedt        Jonas
# 3  0412148992926   2369528    1981  kvinna  Westerén        Hanna
# 4  0879014196003   2369330    1949     man  Åkerlund        Jonas
#
#    sorteringsnamn iort parti                     valkrets  \
# ...

# %% [markdown]
# ### 865 records miss valkrets

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2185 entries, 0 to 2184
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hangar_guid     2185 non-null   object
#  1   sourceid        2185 non-null   object
#  2   intressent_id   2185 non-null   object
#  3   hangar_id       2185 non-null   object
#  4   fodd_ar         2185 non-null   object
#  5   kon             2185 non-null   object
#  6   efternamn       2185 non-null   object
#  7   tilltalsnamn    2185 non-null   object
#  8   sorteringsnamn  2185 non-null   object
#  9   iort            2185 non-null   object
#  10  parti           2185 non-null   object
#  11  valkrets        2185 non-null   object
#  12  status          2185 non-null   object
#  13  person_url_xml  2185 non-null   object
#  14  bild_url_80     2185 non-null   object
#  15  bild_url_192    2185 non-null   object
#  16  bild_url_max    2185 non-null   object
# ...

# %%
dftot.valkrets.value_counts()
# Out:
#                                 865
# Stockholms län                  165
# Stockholms kommun               148
# Göteborgs kommun                 68
# Skåne läns södra                 55
# Uppsala län                      52
# Östergötlands län                49
# Dalarnas län                     48
# Örebro län                       47
# Södermanlands län                46
# Hallands län                     44
# Västra Götalands läns västra     42
# Jönköpings län                   41
# Värmlands län                    39
# Gävleborgs län                   38
# Västerbottens län                38
# Västra Götalands läns norra      37
# Malmö kommun                     37
# Skåne läns västra                36
# Norrbottens län                  34
# Västmanlands län                 34
# Skåne läns norra och östra       33
# Västernorrlands län              33
# Kalmar län                       32
# Västra Götalands läns östra      29
# Västra Götalands läns södra      26
# ...

# %%
#dfValkretsEmpty = dftot[~dftot.valkrets.isnull()]
dfValkretsEmpty = dftot[dftot.valkrets.str.len() == 0]

dfValkretsEmpty.info()


# my_df[~my_df.editions.isnull()]
# Filtering DataFrame to only show rows where 'valkrets' is empty
#filtered_df = person_df[person_df['valkrets'].isna() | person_df['valkrets'].str.isspace()]
#print(filtered_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 865 entries, 5 to 2184
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hangar_guid     865 non-null    object
#  1   sourceid        865 non-null    object
#  2   intressent_id   865 non-null    object
#  3   hangar_id       865 non-null    object
#  4   fodd_ar         865 non-null    object
#  5   kon             865 non-null    object
#  6   efternamn       865 non-null    object
#  7   tilltalsnamn    865 non-null    object
#  8   sorteringsnamn  865 non-null    object
#  9   iort            865 non-null    object
#  10  parti           865 non-null    object
#  11  valkrets        865 non-null    object
#  12  status          865 non-null    object
#  13  person_url_xml  865 non-null    object
#  14  bild_url_80     865 non-null    object
#  15  bild_url_192    865 non-null    object
#  16  bild_url_max    865 non-null    object
# ...

# %%
dfValkretsEmpty
# Out:
#                                hangar_guid  \
# 5     772908f0-07f5-40e0-a073-e0a2d2c1e6cf
# 15    32447d78-65a3-4d27-979e-c9f3fb345b2a
# 20    691b15f9-964e-40db-967c-47c2006f8c6a
# 28    2b3939e7-0f94-4192-b12d-27c3f47b391a
# 33    4139867f-86ff-40e6-a369-78c0473cf7f1
# ...                                    ...
# 2162  ee425c0b-b14c-4ec6-aa65-af29850d1dbe
# 2174  215cbab4-8e74-4b8d-918a-b00b3c709666
# 2182  089393ab-9cfb-4aed-88b8-c8d5f372214c
# 2183  3f34ae7a-b36a-41f6-86dc-a9d86b9d09af
# 2184  85761e74-39fc-4c0d-8bc8-626e3341bb6e
#
#                                   sourceid  intressent_id hangar_id fodd_ar  \
# 5     7b535991-36e4-425e-a7ff-cfd4e61ca95d  0706916743101   2341738    1928
# 15    dba365ea-0007-4a14-9b24-fa56a864271a                  5160840       0
# 20    921ea8a4-27b6-4223-9af3-f37e221fe6e3                  4788851       0
# 28    32a23826-6fd4-4a82-bcef-6bc64df3007d  0618278689611   4467795    1958
# ...

# %%
dfValkretsEmpty.status.value_counts()
# Out:
# Tidigare riksdagsledamot          468
# Tidigare ersättare                 62
# Status saknas                      25
# Tidigare europaparlamentariker     19
# Tidigare statsråd                  18
#                                  ...
# Avliden  2021-01-18                 1
# Avliden  2019-05-24                 1
# Avliden  2012-01-02                 1
# Avliden  2005-10-03                 1
# Ledamot i Partibidragsnämnden       1
# Name: status, Length: 190, dtype: int64

# %%
dfValkretsEmpty.fodd_ar.value_counts()
# Out:
# 0       136
# 1939     44
# 1943     37
# 1937     32
# 1936     31
#        ...
# 1980      1
# 1970      1
# 1982      1
# 1978      1
# 1985      1
# Name: fodd_ar, Length: 70, dtype: int64

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2023-06-01 16:56:08.657093
# Time elapsed (hh:mm:ss.ms) 0:00:15.172320
