# %%
import io

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfinterp import PDFPageInterpreter, PDFResourceManager
from pdfminer.pdfpage import PDFPage

def pdfparser(data):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)

    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    with open(data, 'rb') as fp:
        for page in PDFPage.get_pages(fp,
                                      pagenos, 
                                      maxpages=maxpages,
                                      password=password,
                                      caching=caching,
                                      check_extractable=False):
            interpreter.process_page(page)

    # As pointed out in another answer, this goes outside the loop
    text = retstr.getvalue()

    device.close()
    retstr.close()
    return text

# %%
pdf = "stuglandet_en_guide_till_fri.pdf"
text = pdfparser(pdf)
# Out:
# The PDF <_io.BufferedReader name='stuglandet_en_guide_till_fri.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case

# %%
text
# Out:
# 'Runt om i Sverige finns öppna stugor, \n\nRunt om i Sverige finns öppna stugor, \n\n”Den här boken är årets \n\n”Den här boken är årets \n\ndär vem som helst får övernatta utan \n\ndär vem som helst får övernatta utan \n\natt betala. Det kan vara gamla soldat-\n\natt betala. Det kan vara gamla soldat-\n\ntorp, flottarkojor eller nybyggda \n\ntorp, flottarkojor eller nybyggda \n\ntimmerstugor. \n\ntimmerstugor. \n\nmåste för skog- och \n\nmåste för skog- och \n\nmarkälskare. Det finns \n\nmarkälskare. Det finns \n\nen uppsjö av böcker om \n\nen uppsjö av böcker om \n\nnatur, vandringsleder och \n\nnatur, vandringsleder och \n\ndylikt – men den här är \n\ndylikt – men den här är \n\nspeciell, den här boken är \n\nspeciell, den här boken är \n\ntrollbindande.”\n\ntrollbindande.”\n\nStugorna ger alla som vill en chans att \n\nStugorna ger alla som vill en chans att \n\nkomma nära naturen, utan att punga \n\nkomma nära naturen, utan att punga \n\nDalarnas Tidningar\n\nDalarnas Tidningar\n\nut tusenlappar på utrustning eller \n\nut tusenlappar på utrustning eller \n\nboende. Ofta räcker det med regnjacka, \n\nboende. Ofta räcker det med regnjacka, \n\nbussbiljett, sovsäck och matlåda för  \n\nbussbiljett, sovsäck och matlåda för  \n\natt få tillgång till en mysig, vedeldad \n\natt få tillgång till en mysig, vedeldad \n\n”En alldeles speciell \n\n”En alldeles speciell \n\nguidebok ... passar minst \n\nguidebok ... passar minst \n\nlika bra på soffbordet som \n\nlika bra på soffbordet som \n\ni rygg säcken ... Text och \n\ni rygg säcken ... Text och \n\nstuga långt från stadens stress.\n\nstuga långt från stadens stress.\n\nbilder väcker lusten att \n\nbilder väcker lusten att \n\nupptäcka vårt eget land.”\n\nupptäcka vårt eget land.”\n\nStuglandet är en guidebok till klimatsmart turism, som \n\nStuglandet är en guidebok till klimatsmart turism, som \n\nGöteborgs-Posten\n\nGöteborgs-Posten\n\nmed text och bild vill inspirera läsaren att själv ge sig ut i \n\nmed text och bild vill inspirera läsaren att själv ge sig ut i \n\nnaturen för äventyr och övernattning.\n\nnaturen för äventyr och övernattning.\n\nMoa Karlberg och Kjell Vowles har kartlagt Sveriges  \n\nMoa Karlberg och Kjell Vowles har kartlagt Sveriges  \n\nöppna övernatt nings stugor. Förutom längre reportage \n\nöppna övernatt nings stugor. Förutom längre reportage \n\noch tips för din egen övernattning, guidas du till över  \n\noch tips för din egen övernattning, guidas du till över  \n\n200 stugor med grund läggande fakta om varje stuga  \n\n200 stugor med grund läggande fakta om varje stuga  \n\noch hur du enklast tar dig dit.\n\noch hur du enklast tar dig dit.\n\n”Att läsa Stuglandet är \n\n”Att läsa Stuglandet är \n\nsom att kika in i en  \n\nsom att kika in i en  \n\nskattkammare.”\n\nskattkammare.”\n\nGrus & Guld\n\nGrus & Guld\n\nI denna nya utgåva har författarna kontrollerat och \n\nI denna nya utgåva har författarna kontrollerat och \n\n”Det här är en fantastiskt \n\n”Det här är en fantastiskt \n\nuppdaterat all fakta i boken. Enligt läsares önskemål har \n\nuppdaterat all fakta i boken. Enligt läsares önskemål har \n\nviktig bok – så om du \n\nviktig bok – så om du \n\nden även fått översiktskartor för alla landsändar.\n\nden även fått översiktskartor för alla landsändar.\n\nundrar vad du ska ge \n\nundrar vad du ska ge \n\nbort i present, ha med  \n\nbort i present, ha med  \n\ntill middagen eller köpa \n\ntill middagen eller köpa \n\nhem … då är den här  \n\nhem … då är den här  \n\nboken svaret.”\n\nboken svaret.”\n\nvandringsbloggen.com\n\nvandringsbloggen.com\n\nkjell  \n\nvowles\n\nmoa  \n\nkarlberg\n\nkjell  \nvowles\nmoa  \nkarlberg\n\nKjell Vowles\nMoa Karlberg\n\nKjell Vowles\nMoa Karlberg\n\nvotum\n\nvotum\n\nS\n\nt\n\nu\n\ng\n\nl\n\na\n\nn\n\nd\n\ne\n\nt\n\nS\nt\nu\ng\nl\na\nn\nd\ne\nt\n\nen guide till fria övernattningar\n\nen guide till fria övernattningar\n\nUppdaterad \nutgåva!\n\nUppdaterad \nutgåva!\n\n\x0c.\nn\ne\nd\nu\nj\nb\nr\nö\nf\n\nr\nä\ ...
