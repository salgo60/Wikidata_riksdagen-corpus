# %% [markdown]
# Example using python and a SPARQL query that extract "In Riksdagen kallad" name form stored in the Wikidata property P2561 to a pandas [Dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)
# * This [notebook](https://github.com/salgo60/Wikidata_riksdagen-corpus/blob/main/Notebook/.ipynb_checkpoints/WikidatatoPandas-checkpoint.ipynb)
#   * GITHUB issue [issues/103](https://github.com/welfare-state-analytics/riksdagen-corpus/issues/103#issuecomment-1012289603)
# * example swedish PM [Hjalmar Branting](https://en.wikipedia.org/wiki/Hjalmar_Branting) and his Wikidata object [Q53620#P2561](https://www.wikidata.org/wiki/Q53620#P2561) how its stored in Wikidata ([graph of WD Hjalmar Branting](https://w.wiki/4gM2))
# * related information
#   * [list generated](https://sv.wikipedia.org/wiki/Anv%C3%A4ndare:Salgo60/Iriksdagenkallad) of what we have in Wikidata with "In Riksdagen kallad"
#     * same list but with [pictures](https://sv.wikipedia.org/wiki/Anv%C3%A4ndare:Salgo60/Iriksdagenkalladbild)
#     * [list](https://sv.wikipedia.org/wiki/Anv%C3%A4ndare:Salgo60/Iriksdagenkalladsamma) were the same namestring is used - Wikidata has today about 10% done
#   * template [Iriksdagenkallad](https://sv.wikipedia.org/wiki/Mall:Iriksdagenkallad) created in sv:WIkipedia to present this Wikidata text string in Swedish Wikipedia article
#   * sv:Wikipedia article explaining "[In Riksdagen kallad](https://sv.wikipedia.org/wiki/I_riksdagen_kallad)"

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-01-14 05:55:47.698899

# %%
# function that returns pandas Dataframe
import sys,json
import pandas as pd 
def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"
 
# https://w.wiki/4gN4 as image grid https://w.wiki/4gN6
query = """#title: Images people with nameform "I Riksdagen kallad"
SELECT DISTINCT ?nameUsedinSwedishPM ?nr ?item ?itemLabel ?itemAltLabel ?img ?svWikipedia WHERE {
  # ?item p:P2561 ?nameSwedishPMp.
  OPTIONAL { ?item wdt:P18 ?img. }
  {
    {
      # ?nameSwedishPMp ps:P2561 ?nameUsedinSwedishPM;
        pq:P3831 wd:Q110382440.
      OPTIONAL { ?nameSwedishPMp pq:P1545 ?nr. }
    }
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
  OPTIONAL {
    # ?svWikipedia schema:about ?item;
      schema:inLanguage "sv";
      schema:isPartOf <https://sv.wikipedia.org/>.
  }
}
ORDER BY (?nameUsedinSwedishPM) (?nr)"""




WDRiksdagentot = get_sparql_dataframe(endpoint_url, query)

# %%
WDRiksdagentot.shape
# Out:
# (556, 7)

# %%
WDRiksdagentot
# Out:
#                  nameUsedinSwedishPM    nr  \
# 0            Abrahamsson i Jönköping     1
# 1    Adelsköld i Nolhaga o Stockholm     1
# 2               Adlersparre i Arvika     2
# 3           Adlersparre i Gustafsvik     1
# 4               Adolfsson i Göteborg     2
# ..                               ...   ...
# 551              Åkerman i Strömstad  None
# 552                Öhman i Stockholm     1
# 553               Öhvall i Bergnäset  None
# 554                  Östling i Valbo     1
# 555              Östlund i Stockholm     1
#
#                                         item              itemLabel  \
# 0    http://www.wikidata.org/entity/Q5627413           Erik Edström
# 1     http://www.wikidata.org/entity/Q384847  Claes Adolf Adelsköld
# 2    http://www.wikidata.org/entity/Q5542896     Rudolf Adlersparre
# 3    http://www.wikidata.org/entity/Q5542896     Rudolf Adlersparre
# 4    http://www.wikidata.org/entity/Q5410165       Gunnar Adolfsson
# ..                                       ...                    ...
# 551  http://www.wikidata.org/entity/Q6255333          Assar Åkerman
# 552  http://www.wikidata.org/entity/Q6256712           Gunnar Öhman
# 553  http://www.wikidata.org/entity/Q6256938          Bertil Öhvall
# 554  http://www.wikidata.org/entity/Q6258086           Olof Östling
# 555  http://www.wikidata.org/entity/Q4691677           Agda Östlund
#
#                                           itemAltLabel  \
# 0    Erik Rudolf Abrahamsson, Abrahamsson i Jönköpi...
# 1                      Adelsköld i Nolhaga o Stockholm
# 2       Adlersparre i Arvika, Adlersparre i Gustafsvik
# 3       Adlersparre i Arvika, Adlersparre i Gustafsvik
# 4              Adolfsson i Göteborg, Adolfsson i Malmö
# ..                                                 ...
# 551                                Åkerman i Strömstad
# 552                                  Öhman i Stockholm
# 553            Öhvall i Bergnäset, Oscar Bertil Öhvall
# 554                                    Östling i Valbo
# 555  Agda Lundgren, Agda Maria Östlund, Östlund i S...
#
#                                                    img  \
# 0    http://commons.wikimedia.org/wiki/Special:File...
# 1    http://commons.wikimedia.org/wiki/Special:File...
# 2    http://commons.wikimedia.org/wiki/Special:File...
# 3    http://commons.wikimedia.org/wiki/Special:File...
# 4    http://commons.wikimedia.org/wiki/Special:File...
# ..                                                 ...
# 551  http://commons.wikimedia.org/wiki/Special:File...
# 552  http://commons.wikimedia.org/wiki/Special:File...
# 553  http://commons.wikimedia.org/wiki/Special:File...
# 554  http://commons.wikimedia.org/wiki/Special:File...
# 555  http://commons.wikimedia.org/wiki/Special:File...
#
#                                            svWikipedia
# 0    https://sv.wikipedia.org/wiki/Erik_Abrahamsson...
# 1    https://sv.wikipedia.org/wiki/Claes_Adelsk%C3%...
# 2     https://sv.wikipedia.org/wiki/Rudolf_Adlersparre
# 3     https://sv.wikipedia.org/wiki/Rudolf_Adlersparre
# 4       https://sv.wikipedia.org/wiki/Gunnar_Adolfsson
# ..                                                 ...
# 551   https://sv.wikipedia.org/wiki/Assar_%C3%85kerman
# 552    https://sv.wikipedia.org/wiki/Gunnar_%C3%96hman
# 553   https://sv.wikipedia.org/wiki/Bertil_%C3%96hvall
# 554    https://sv.wikipedia.org/wiki/Olof_%C3%96stling
# 555    https://sv.wikipedia.org/wiki/Agda_%C3%96stlund
#
# [556 rows x 7 columns]

# %% [markdown]
# ### Getting more data from Wikidata
# * Birth [P569](https://www.wikidata.org/wiki/Property:P569)
# * Death [P570](https://www.wikidata.org/wiki/Property:P570)
#
# SPARQL https://w.wiki/4gP6

# %%
# https://w.wiki/4gP6
queryMore1 = """
SELECT DISTINCT ?nameUsedinSwedishPM ?nr ?item ?itemLabel ?itemAltLabel ?birth ?death WHERE {
  # ?item p:P2561 ?nameSwedishPMp.
  OPTIONAL { ?item wdt:P569 ?birth. }
  OPTIONAL { ?item wdt:P570 ?death. }
  {
    {
      # ?nameSwedishPMp ps:P2561 ?nameUsedinSwedishPM;
        pq:P3831 wd:Q110382440.
      OPTIONAL { ?nameSwedishPMp pq:P1545 ?nr. }
    }
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "sv,en". }
}
ORDER BY (?item) (xsd:integer(?nr))""" 

WDRiksdagentotMore1 = get_sparql_dataframe(endpoint_url, queryMore1)

# %%
WDRiksdagentotMore1[0:40]
# Out:
#            nameUsedinSwedishPM    nr  \
# 0        Lundström i Stockholm     1
# 1      Janson i Hennickehammar  None
# 2        Andreasson i Tollered     1
# 3           Olson i Stensdalen  None
# 4           Pehrsson i Önnerud     1
# 5         Åkerlund i Druvefors     1
# 6           Billqvist i Skövde  None
# 7            Andersson i Malmö  None
# 8          Gansmoe i Hägersten     1
# 9           Henningson i Visby     1
# 10   Hedström i Västra Skymnäs     1
# 11             Månsson i Backa     1
# 12          Lantto i Stocksund     1
# 13      Permansson i Erikslund  None
# 14             Holm i Jonsgård  None
# 15         Andersson i Kolstad  None
# 16              Julin i Åmberg     1
# 17       Nilsson i Kungsberget     1
# 18        Hulting i Herrljunga     1
# 19              Ekelund i Lund     1
# 20          Rosvall i Dösjebro     1
# 21         Wigforss i Göteborg     1
# 22       Andersson i Stockholm     1
# 23            Brandt i Söderby     1
# 24           Meyer i Karlshamn     1
# 25        von Koch i Stockholm     1
# 26        von Koch i Djursholm     2
# 27          Andersson i Rasjön  None
# 28       Thunborg i Skärholmen  None
# 29  Carlsson i Norra Smedstorp  None
# 30          Gustafsson i Borås     1
# 31           Ohlin i Stockholm     1
# 32   Arvidsson i Storbrohyttan     1
# 33           Rydberg i Barkaby  None
# 34            Wohlin i Uppsala     1
# 35          Wohlin i Stockholm     2
# 36          Hagman i Domnarvet     1
# 37              Alin i Uppsala     1
# 38     Lagerstråle i Stockholm     1
# 39       Hamilton i Hedenlunda     1
#
#                                          item  \
# 0     http://www.wikidata.org/entity/Q1037831
# 1   http://www.wikidata.org/entity/Q104851791
# 2   http://www.wikidata.org/entity/Q104918428
# 3   http://www.wikidata.org/entity/Q105046298
# 4   http://www.wikidata.org/entity/Q105046955
# 5   http://www.wikidata.org/entity/Q105062126
# 6   http://www.wikidata.org/entity/Q110278693
# 7   http://www.wikidata.org/entity/Q110321926
# 8   http://www.wikidata.org/entity/Q110401403
# 9   http://www.wikidata.org/entity/Q110426890
# 10  http://www.wikidata.org/entity/Q110436560
# 11  http://www.wikidata.org/entity/Q110436946
# 12  http://www.wikidata.org/entity/Q110439181
# 13  http://www.wikidata.org/entity/Q110440831
# 14  http://www.wikidata.org/entity/Q110440981
# 15  http://www.wikidata.org/entity/Q110442451
# 16  http://www.wikidata.org/entity/Q110467944
# 17  http://www.wikidata.org/entity/Q110528102
# 18  http://www.wikidata.org/entity/Q110530109
# 19  http://www.wikidata.org/entity/Q110541107
# 20  http://www.wikidata.org/entity/Q110544246
# 21    http://www.wikidata.org/entity/Q1145662
# 22    http://www.wikidata.org/entity/Q1346478
# 23    http://www.wikidata.org/entity/Q1353856
# 24    http://www.wikidata.org/entity/Q1358123
# 25    http://www.wikidata.org/entity/Q1511698
# 26    http://www.wikidata.org/entity/Q1511698
# 27    http://www.wikidata.org/entity/Q1555406
# 28   http://www.wikidata.org/entity/Q16084072
# 29   http://www.wikidata.org/entity/Q16649068
# 30   http://www.wikidata.org/entity/Q16945247
# 31     http://www.wikidata.org/entity/Q179493
# 32   http://www.wikidata.org/entity/Q18237396
# 33   http://www.wikidata.org/entity/Q18245538
# 34    http://www.wikidata.org/entity/Q1992475
# 35    http://www.wikidata.org/entity/Q1992475
# 36   http://www.wikidata.org/entity/Q19976568
