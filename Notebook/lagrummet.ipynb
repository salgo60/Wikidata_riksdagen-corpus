# %% [markdown]
# ## Hämta Lagrummet URL
#
#
# https://lagrummet.se/lagrummet/rattsinformation/myndigheters-foreskrifter

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-11-13 13:42:05.096564

# %%
import requests
import urllib.request
import time
from tqdm import tqdm
from bs4 import BeautifulSoup
def cleanupstring(s):
    out_s = s
    while '  ' in out_s:
        out_s = out_s.strip().replace('  ', ' ')
    return out_s, len(s)-len(out_s)

urlbase = "https://lagrummet.se/lagrummet/rattsinformation/myndigheters-foreskrifter"

newList = []

url = urlbase
print(url)
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
urls = soup.findAll('a')
for u in urls:
    if ("lagrum" or "om-webbplatsen") not in u['href']:
        print (u['href'],u.text)
        newList.append([u.text,u['href'])

    
print (len(newList) ," antal poster")
# Out:
#   File "<ipython-input-21-44a746ad7a9f>", line 24
#     newList.append([u.text,u['href'])
#                                     ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
#newList

# %%
import pandas as pd
df = pd.DataFrame(newList)
df.to_csv("GravstensinvKyrkog2.csv")

# %%
#newList
# Out:
# [[1, 'Asarums kyrkogård'],
#  [2, 'Ringamåla kyrkogård'],
#  [3, 'Bräkne-Hoby gamla kyrkogård'],
#  [4, 'Bräkne-Hoby nya kyrkogård'],
#  [5, 'Bräkne-Hoby södra kyrkogård'],
#  [6, 'Bräkne-Hoby västra kyrkogård'],
#  [7, 'Fridlevstads kyrkogård'],
#  [8, 'Sillhövda kyrkogård'],
#  [9, 'Tvings kyrkogård'],
#  [10, 'Gammalstorps kyrkogård'],
#  [11, 'Ysane kyrkogård'],
#  [12, 'Jämjö kyrkogård'],
#  [13, 'Avaskärs kyrkogård'],
#  [14, 'Hoppsan! Sidan kunde inte hittas'],
#  [15, 'Kristianopels kyrkogård'],
#  [16, 'Ramdala kyrkogård'],
#  [17, 'Sturkö kyrkogård'],
#  [18, 'Tjurkö kyrkogård'],
#  [19, 'Torhamns kyrkogård'],
#  [20, 'Jämshögs kyrkogård'],
#  [21, 'Hoppsan! Sidan kunde inte hittas'],
#  [22, 'Hällaryds kyrkogård'],
#  [23, 'Åryds kyrkogård'],
#  [24, 'Boöns kyrkogård'],
#  [25, 'Carl Gustafs kyrkogård Karlshamn'],
#  [26, 'Hvilans kyrkogård, Karlshamn'],
#  [27, 'Karlshamns kolerakyrkogård'],
#  [28, 'Hoppsan! Sidan kunde inte hittas'],
#  [29, 'Karlskrona griftegård'],
#  [30, 'Karlskrona judiska begravningsplats'],
#  [31, 'Karlskrona muslimska begravningsplats'],
#  [32, 'Vämö kyrkogård'],
#  [33, 'Aspö kyrkogård'],
#  [34, 'Kyrkhults kyrkogård'],
#  [35, 'Augerums kyrkogård'],
#  [36, 'Flymens kyrkogård'],
#  [37, 'Hoppsan! Sidan kunde inte hittas'],
#  [38, 'Lösens kyrkogård'],
#  [39, 'Elleholms kyrkogård'],
#  [40, 'Mörrums kyrkogård'],
#  [41, 'Hasslö kyrkogård'],
#  [42, 'Nättraby kyrkogård'],
#  [43, 'Rödeby askgravlund'],
#  [44, 'Rödeby kyrkogård'],
#  [45, 'Hoppsan! Sidan kunde inte hittas'],
#  [46, 'Backaryds kyrkogård'],
#  [47, 'Backaryds västra kyrkogård'],
#  [48, 'Hoppsan! Sidan kunde inte hittas'],
#  [49, 'Hoppsan! Sidan kunde inte hittas'],
#  [50, 'Bredåkra kyrkogård'],
#  [51, 'Hoppsan! Sidan kunde inte hittas'],
#  [52, 'Edestads kyrkogård'],
#  [53, 'Eringsboda kyrkogård'],
#  [54, 'Förkärla kyrkogård'],
#  [55, 'Hjortsberga kyrkogård'],
#  [56, 'Göholms kyrkogård'],
#  [57, 'Listerby kyrkogård'],
#  [58, 'Hoppsan! Sidan kunde inte hittas'],
#  [59, 'Saxemara kyrkogård'],
#  [60, 'Öljehults kyrkogård'],
#  [61, 'Sölvesborgs kapellkyrkogård'],
#  [62, 'Sölvesborgs Slottskyrkogården'],
#  [63, 'Sölvesborgs östra kyrkogård'],
#  [64, 'Mjällby kyrkogård'],
#  [65, 'Åls kyrkogård'],
#  [66, 'Evertsbergs kyrkogård'],
#  [67, 'Nornäs kyrkogård'],
#  [68, 'Åsens kyrkogård'],
#  [69, 'Älvdalens gamla kyrkogård'],
#  [70, 'Älvdalens västra kyrkogård'],
#  [71, 'Älvdalens östra kyrkogård'],
#  [72, 'Ärnäs kyrkogård'],
#  [73, 'Avesta kyrkogård'],
#  [74, 'Bjursås kyrkogård'],
#  [75, 'Sågmyra kyrkogård'],
#  [76, 'By gamla kyrkogård'],
#  [77, 'By nya kyrkogård'],
#  [78, 'Horndals kyrkogård'],
#  [79, 'Envikens kyrkogård'],
#  [80, 'Aspeboda kyrkogård'],
#  [81, 'Hästbergs nya kyrkogård'],
#  [82, 'Falu skogskyrkogård'],
#  [83, 'Hästbergs gamla kyrkogård'],
#  [84, 'Kämparvets kyrkogård'],
#  [85, 'Norslunds kyrkogård'],
#  [86, 'Grycksbo kyrkogård'],
#  [87, 'Hosjö kyrkogård'],
#  [88, 'Stora Kopparbergs kyrkogård'],
#  [89, 'Vika kyrkogård'],
#  [90, 'Folkärna kyrkogård'],
#  [91, 'Floda kyrkogård'],
#  [92, 'Gagnefs kyrkogård'],
#  [93, 'Mockfjärds kyrkogård'],
#  [94, 'Grangärde kyrkogård'],
#  [95, 'Grängesbergs kyrkogård'],
#  [96, 'Säfsnäs kyrkogård'],
#  [97, 'Grytnäs kyrkogård'],
#  [98, 'Garpenbergs kyrkogård'],
#  [99, 'Hedemora kyrkogård'],
#  [100, 'Hoppsan! Sidan kunde inte hittas'],
#  [101, 'Hoppsan! Sidan kunde inte hittas'],
#  [102, 'Husby kyrkogård'],
#  [103, 'Långshyttans kyrkogård'],
#  [104, 'Stjärnsunds kyrkogård'],
#  [105, 'Hoppsan! Sidan kunde inte hittas'],
#  [106, 'Hoppsan! Sidan kunde inte hittas'],
#  [107, 'Gördalens begravningsplats'],
#  [108, 'Särna kyrkogård'],
#  [109, 'Lima kyrkogård'],
#  [110, 'Lima södra kyrkogård'],
#  [111, 'Lötens kyrkogård'],
#  [112, 'Rörbäcksnäs kyrkogård'],
#  [113, 'Hoppsan! Sidan kunde inte hittas'],
#  [114, 'Hoppsan! Sidan kunde inte hittas'],
#  [115, 'Sörsjöns begravningsplats'],
#  [116, 'Transtrands kyrkogård'],
#  [117, 'Järna kyrkogård'],
#  [118, 'Nås kyrkogård'],
#  [119, 'Vansbro kyrkogård'],
#  [120, 'Äppelbo kyrkogård'],
#  [121, 'Djura kyrkogård'],
#  [122, 'Leksands kyrkogård'],
#  [123, 'Siljansnäs kyrkogård'],
#  [124, 'Ludvika gamla kyrkogård'],
#  [125, 'Lyvikens kyrkogård'],
#  [126, 'Fors kyrkogård'],
#  [127, 'Malungs kyrkogård'],
#  [128, 'Yttermalungs kyrkogård'],
#  [129, 'Öje kyrkogård'],
#  [130, 'Tyngsjö kyrkogård'],
#  [131, 'Mora gamla kyrkogård'],
#  [132, 'Mora nya begravningsplats'],
#  [133, 'Oxbergs kyrkogård'],
#  [134, 'Siknäs kyrkogård'],
#  [135, 'Ulvsjö skogskyrkogård'],
#  [136, 'Sollerö kyrkogård'],
#  [137, 'Venjans kyrkogård'],
#  [138, 'Våmhus kyrkogård'],
#  [139, 'Norrbärke kyrkogård'],
#  [140, 'Ore kyrkogård'],
#  [141, 'Kvarnbergs gamla kyrkogård'],
#  [142, 'Kvarnbergs nya kyrkogård'],
#  [143, 'Myggsjö kyrkogård'],
#  [144, 'Hoppsan! Sidan kunde inte hittas'],
#  [145, 'Orsa gamla kyrkogård'],
#  [146, 'Orsa nya kyrkogård'],
#  [147, 'Skattunge kyrkogård'],
#  [148, 'Bingsjö kyrkogård'],
#  [149, 'Dådrans kyrkogård'],
#  [150, 'Boda gamla kyrkogård'],
#  [151, 'Boda nya kyrkogård'],
#  [152, 'Rättviks kyrkogård'],
#  [153, 'Gustafs gamla kyrkogård'],
#  [154, 'Gustafs nya kyrkogård'],
#  [155, 'Gustafs västra kyrkogård'],
#  [156, 'Hoppsan! Sidan kunde inte hittas'],
#  [157, 'Stora Skedvi kyrkogård'],
#  [158, 'Säters kyrkogård'],
#  [159, 'Malingsbo kyrkogård'],
#  [160, 'Söderbärke kyrkogård'],
#  [161, 'Amsbergs kyrkogård'],
#  [162, 'Smälla griftegård'],
#  [163, 'Stora Tuna kyrkogård'],
#  [164, 'Stora Tuna norra griftegård'],
#  [165, 'Hoppsan! Sidan kunde inte hittas'],
#  [166, 'Torsångs kyrkogård'],
#  [167, 'Torsångs griftegård'],
#  [168, 'Sundborns kyrkogård'],
#  [169, 'Svartnäs kyrkogård'],
#  [170, 'Lumshedens kyrkogård'],
#  [171, 'Svärdsjö kyrkogård'],
#  [172, 'Fardhems kyrkogård'],
#  [173, 'Gerums kyrkogård'],
#  [174, 'Levide kyrkogård'],
#  [175, 'Linde kyrkogård'],
#  [176, 'Lojsta kyrkogård'],
#  [177, 'Alva kyrkogård'],
#  [178, 'Hemse kyrkogård'],
#  [179, 'Rone kyrkogård'],
#  [180, 'Bunge kyrkogård'],
#  [181, 'Fleringe gamla kyrkogård'],
#  [182, 'Fårö kyrkogård'],
#  [183, 'Gotska sandön'],
#  [184, 'Rute kyrkogård'],
#  [185, 'Burs kyrkogård'],
#  [186, 'Lau kyrkogård'],
#  [187, 'Närs kyrkogård'],
#  [188, 'Stånga kyrkogård'],
#  [189, 'Dalhems kyrkogård'],
#  [190, 'Ekeby kyrkogård'],
#  [191, 'Ganthems kyrkogård'],
#  [192, 'Hörsne kyrkogård'],
#  [193, 'Atlingbo kyrkogård'],
#  [194, 'Eskelhems kyrkogård'],
#  [195, 'Hogräns kyrkogård'],
#  [196, 'Tofta kyrkogård'],
#  [197, 'Valls kyrkogård'],
#  [198, 'Alskogs kyrkogård'],
#  [199, 'Ardre kyrkogård'],
#  [200, 'Etelhems kyrkogård'],
#  [201, 'Garde kyrkogård'],
#  [202, 'Lye kyrkogård'],
#  [203, 'Gothems kyrkogård'],
#  [204, 'Källunge kyrkogård'],
#  [205, 'Norrlanda kyrkogård'],
#  [206, 'Vallstena kyrkogård'],
#  [207, 'Eke kyrkogård'],
#  [208, 'Grötlingbo kyrkogård'],
#  [209, 'Hablingbo kyrkogård'],
#  [210, 'Havdhems kyrkogård'],
#  [211, 'Näs kyrkogård'],
#  [212, 'Silte kyrkogård'],
#  [213, 'Eksta kyrkogård'],
#  [214, 'Fröjels kyrkogård'],
#  [215, 'Hejde kyrkogård'],
#  [216, 'Klinte kyrkogård'],
#  [217, 'Mästerby kyrkogård'],
#  [218, 'Sanda kyrkogård'],
#  [219, 'Sproge kyrkogård'],
#  [220, 'Västergarns kyrkogård'],
#  [221, 'Väte kyrkogård'],
#  [222, 'Halls kyrkogård'],
#  [223, 'Hangvars kyrkogård'],
#  [224, 'Hellvi kyrkogård'],
#  [225, 'Lärbro kyrkogård'],
#  [226, 'Ala kyrkogård'],
#  [227, 'Anga kyrkogård'],
#  [228, 'Gammelgarns kyrkogård'],
#  [229, 'Kräklingbo kyrkogård'],
#  [230, 'Östergarns kyrkogård'],
#  [231, 'Boge kyrkogård'],
#  [232, 'Othems kyrkogård'],
#  [233, 'Slite kyrkogård'],
#  [234, 'Akebäcks kyrkogård'],
#  [235, 'Barlingbo kyrkogård'],
#  [236, 'Björke kyrkogård'],
#  [237, 'Endre kyrkogård'],
#  [238, 'Follingbo kyrkogård'],
#  [239, 'Hejdeby kyrkogård'],
#  [240, 'Roma kyrkogård'],
#  [241, 'Stenkumla kyrkogård'],
#  [242, 'Träkumla kyrkogård'],
#  [243, 'Västerhejde kyrkogård'],
#  [244, 'Lummelunda kyrkogård'],
#  [245, 'Martebo kyrkogård'],
#  [246, 'Stenkyrka kyrkogård'],
#  [247, 'Tingstäde kyrkogård'],
#  [248, 'Fide kyrkogård'],
#  [249, 'Hamra kyrkogård'],
#  [250, 'Sundre kyrkogård'],
#  [251, 'Vamlingbo kyrkogård'],
#  [252, 'Öja kyrkogård'],
#  [253, 'Bro kyrkogård'],
#  [254, 'Bäls kyrkogård'],
#  [255, 'Fole kyrkogård'],
#  [256, 'Hejnums kyrkogård'],
#  [257, 'Lokrume kyrkogård'],
#  [258, 'Väskinde kyrkogård'],
#  [259, 'Visby norra kyrkogård'],
#  [260, 'Visby södra kyrkogård'],
#  [261, 'Visby östra kyrkogård'],
#  [262, 'Buttle kyrkogård'],
#  [263, 'Guldrupe kyrkogård'],
#  [264, 'Halla kyrkogård'],
#  [265, 'Sjonhems kyrkogård'],
#  [266, 'Viklau kyrkogård'],
#  [267, 'Vänge kyrkogård'],
#  [268, 'Årsunda kyrkogård'],
#  [269, 'Österfärnebo kyrkogård'],
#  [270, 'Ilsbo kyrkogård'],
#  [271, 'Bergsjö kyrkogård'],
#  [272, 'Hassela kyrkogård'],
#  [273, 'Bjuråkers kyrkogård'],
#  [274, 'Norrbo kyrkogård'],
#  [275, 'Delsbo gamla kyrkogård'],
#  [276, 'Delsbo nya kyrkogård'],
#  [277, 'Enångers kyrkogård'],
#  [278, 'Nianfors kyrkogård'],
#  [279, 'Njutångers kyrkogård'],
#  [280, 'Färila kyrkogård'],
#  [281, 'Hoppsan! Sidan kunde inte hittas'],
#  [282, 'Kårböle kyrkogård'],
#  [283, 'Los kyrkogård'],
#  [284, 'Forsa kyrkogård'],
#  [285, 'Högs kyrkogård'],
#  [286, 'Gävle gamla kyrkogård'],
#  [287, 'Gävle skogskyrkogård'],
#  [288, 'Bomhus kyrkogård'],
#  [289, 'Hälsingtuna kyrkogård'],
#  [290, 'Rogsta kyrkogård'],
#  [291, 'Hamrånge kyrkogård'],
#  [292, 'Österheds begravningsplats'],
#  [293, 'Gnarps kyrkogård'],
#  [294, 'Harmångers kyrkogård'],
#  [295, 'Jättendals kyrkogård'],
#  [296, 'Hedesunda kyrkogård'],
#  [297, 'Hofors kyrkogård'],
#  [298, 'Sofiedals griftegård'],
#  [299, 'Idenors kyrkogård'],
#  [300, 'Jakobs kyrkogård'],
#  [301, 'Hille kyrkogård'],
#  [302, 'Järvsö gamla kyrkogård'],
#  [303, 'Järvsö mellankyrkogård'],
#  [304, 'Hoppsan! Sidan kunde inte hittas'],
#  [305, 'Järvsö ängskyrkogård'],
#  [306, 'Alfta kyrkogård'],
#  [307, 'Annefors kyrkogård'],
#  [308, 'Arbrå kyrkogård'],
#  [309, 'Bollnäs gamla kyrkogård'],
#  [310, 'Hoppsan! Sidan kunde inte hittas'],
#  [311, 'Bollnäs nya kyrkogård'],
#  [312, 'Hoppsan! Sidan kunde inte hittas'],
#  [313, 'Bollnäs S:t Lars kyrkogård'],
#  [314, 'Gruvbergets kyrkogård'],
#  [315, 'Katrinebergs kyrkogård'],
#  [316, 'Hanebo gamla kyrkogård'],
#  [317, 'Hanebo södra kyrkogård'],
#  [318, 'Hanebo östra kyrkogård'],
#  [319, 'Ovanåkers kyrkogård'],
#  [320, 'Öjungs kyrkogård'],
#  [321, 'Rengsjö kyrkogård'],
#  [322, 'Segersta kyrkogård'],
#  [323, 'Svabensverks kyrkogård'],
#  [324, 'Undersviks kyrkogård'],
#  [325, 'Mattsmyra kyrkogård'],
#  [326, 'Voxna kyrkogård'],
#  [327, 'Ljusdals norra kyrkogård'],
#  [328, 'Ljusdals södra kyrkogård'],
#  [329, 'Ljusdals västra kyrkogård'],
#  [330, 'Ramsjö kyrkogård'],
#  [331, 'Ramsjö skogskyrkogård'],
#  [332, 'Valsjöns kyrkogård'],
#  [333, 'Norrala kyrkogård'],
#  [334, 'Trönö kyrkogård'],
#  [335, 'Lingbo kyrkogård'],
#  [336, 'Jädraås skogskyrkogård'],
#  [337, 'Ockelbo kyrkogård'],
#  [338, 'Åmots kapellkyrkogård'],
#  [339, 'Åmots nya kyrkogård'],
#  [340, 'Åmots skogskyrkogård'],
#  [341, 'Järbo kyrkogård'],
#  [342, 'Ovansjö kyrkogård'],
#  [343, 'Högbo kyrkogård'],
#  [344, 'Sandvikens gamla kyrkogård'],
#  [345, 'Hoppsan! Sidan kunde inte hittas'],
#  [346, 'Sandvikens södra kyrkogård'],
#  [347, 'Skogs kyrkogård'],
#  [348, 'Bergviks kyrkogård'],
#  [349, 'Ljusne kyrkogård'],
#  [350, 'Mo kyrkogård'],
#  [351, 'Söderala kyrkogård'],
#  [352, 'Sandarne gamla kyrkogård'],
#  [353, 'Sandarne nya kyrkogård'],
#  [354, 'Söderhamns kyrkogård'],
#  [355, 'Torsåkers kyrkogård'],
#  [356, 'Forsbacka kyrkogård'],
#  [357, 'Valbo kyrkogård'],
#  [358, 'Enslövs kyrkogård'],
#  [359, 'Fagereds kyrkogård'],
#  [360, 'Källsjö kyrkogård'],
#  [361, 'Ullareds kyrkogård'],
#  [362, 'Älvsereds kyrkogård'],
#  [363, 'Falkenbergs kapellkyrkogård'],
#  [364, 'Falkenbergs skogskyrkogård'],
#  [365, 'Skrea kyrkogård'],
#  [366, 'Femsjö kyrkogård'],
#  [367, 'Färgaryds kyrkogård'],
#  [368, 'Fjärås kyrkogård'],
#  [369, 'Förlanda kyrkogård'],
#  [370, 'Frillesås kyrkogård'],
#  [371, 'Gällinge kyrkogård'],
#  [372, 'Idala kyrkogård'],
#  [373, 'Getinge kyrkogård'],
#  [374, 'Rävinge kyrkogård'],
#  [375, 'Gunnarps kyrkogård'],
#  [376, 'Gällareds kyrkogård'],
#  [377, 'Krogsereds kyrkogård'],
#  [378, 'Hoppsan! Sidan kunde inte hittas'],
#  [379, 'Halmstads norra kyrkogård'],
#  [380, 'Halmstads västra kyrkogård gamla'],
#  [381, 'Halmstads västra kyrkogård nya'],
#  [382, 'Karlsro kyrkogård'],
#  [383, 'Holms kyrkogård'],
#  [384, 'Sperlingsholms kyrkogård'],
#  [385, 'Hoppsan! Sidan kunde inte hittas'],
#  [386, 'Harplinge kyrkogård'],
#  [387, 'Steninge kyrkogård'],
#  [388, 'Hasslövs kyrkogård'],
#  [389, 'Våxtorps kyrkogård'],
#  [390, 'Grimetons kyrkogård'],
#  [391, 'Gödestads kyrkogård'],
#  [392, 'Hunnestads kyrkogård'],
#  [393, 'Nösslinge kyrkogård'],
#  [394, 'Rolfstorps kyrkogård'],
#  [395, 'Skällinge kyrkogård'],
#  [396, 'Hishults kyrkogård'],
#  [397, 'Knäreds kyrkogård'],
#  [398, 'Hanhals nedre kyrkogård'],
#  [399, 'Hanhals övre kyrkogård'],
#  [400, 'Hoppsan! Sidan kunde inte hittas'],
#  [401, 'Kungsbacka gamla kyrkogård'],
#  [402, 'Hoppsan! Sidan kunde inte hittas'],
#  [403, 'Kungsbacka skogskyrkogård'],
#  [404, 'Laholm, S:t Clemens kyrkogård'],
#  [405, 'Laholms kyrkogård'],
#  [406, 'Skogaby kapell'],
#  [407, 'Skummeslövs kyrkogård'],
#  [408, 'Jälluntofta kyrkogård'],
#  [409, 'Långaryds kyrkogård'],
#  [410, 'Södra Unnaryds kyrkogård'],
#  [411, 'Lindbergs kyrkogård'],
#  [412, 'Stamnareds kyrkogård'],
#  [413, 'Torpa kyrkogård'],
#  [414, 'Valinge kyrkogård'],
#  [415, 'Morups kyrkogård'],
#  [416, 'Landa kyrkogård'],
#  [417, 'Ölmevalla kyrkogård'],
#  [418, 'Onsala kyrkogård'],
#  [419, 'Oskarströms kyrkogård'],
#  [420, 'Ränneslövs kyrkogård'],
#  [421, 'Ysby kyrkogård'],
#  [422, 'Kvibille kyrkogård'],
#  [423, 'Slättåkra kyrkogård'],
#  [424, 'Breareds kyrkogård'],
#  [425, 'Eldsberga kyrkogård'],
#  [426, 'Snöstorps kyrkogård'],
#  [427, 'Trönninge kyrkogård'],
#  [428, 'Tönnersjö kyrkogård'],
#  [429, 'Söndrums kyrkogård'],
#  [430, 'Vapnö kyrkogård'],
#  [431, 'Stafsinge ödekyrkogård'],
#  [432, 'Stafsinge kyrkogård'],
#  [433, 'Abilds kyrkogård'],
#  [434, 'Asige kyrkogård'],
#  [435, 'Eftra gamla kyrkogård'],
#  [436, 'Slöinge kyrkogård'],
#  [437, 'Årstads kyrkogård'],
#  [438, 'Tölö kyrkogård'],
#  [439, 'Älvsåkers kyrkogård'],
#  [440, 'Drängsereds kyrkogård'],
#  [441, 'Kinnareds kyrkogård'],
#  [442, 'Rydöbruks kapell'],
#  [443, 'Torups kyrkogård'],
#  [444, 'Träslövs kyrkogård'],
#  [445, 'Dagsås kyrkogård'],
#  [446, 'Sibbarps kyrkogård'],
#  [447, 'Spannarps kyrkogård'],
#  [448, 'Tvååkers kyrkogård'],
#  [449, 'Släps kyrkogård'],
#  [450, 'Vallda kyrkogård'],
#  [451, 'S:t Jörgens kyrkogård'],
#  [452, 'Varbergs östra kyrkogård'],
#  [453, 'Stråvalla kyrkogård'],
#  [454, 'Värö kyrkogård'],
#  [455, 'Grimmareds kyrkogård'],
#  [456, 'Gunnarsjö kyrkogård'],
#  [457, 'Karl Gustavs kyrkogård'],
#  [458, 'Kungsäters gamla kyrkogård'],
#  [459, 'Sällstorps kyrkogård'],
#  [460, 'Veddige kyrkogård'],
#  [461, 'Ås kyrkogård'],
#  [462, 'Tjärby kyrkogård'],
#  [463, 'Mästocka kyrkogård'],
#  [464, 'Veinge kyrkogård'],
#  [465, 'Alfshögs kyrkogård'],
#  [466, 'Askome kyrkogård'],
#  [467, 'Köinge kyrkogård'],
#  [468, 'Okome kyrkogård'],
#  [469, 'Svartrå kyrkogård'],
#  [470, 'Vessige kyrkogård'],
#  [471, 'Ljungby kyrkogård'],
#  [472, 'Vinbergs kyrkogård'],
#  [473, 'Duveds kyrkogård'],
#  [474, 'Handöls kyrkogård'],
#  [475, 'Åre kyrkogård'],
#  [476, 'Bräcke kyrkogård'],
#  [477, 'Nyhems kyrkogård'],
#  [478, 'Brunflo kyrkogård'],
#  [479, 'Lockne kyrkogård'],
#  [480, 'Marieby kyrkogård'],
#  [481, 'Näs kyrkogård'],
#  [482, 'Föllinge kyrkogård'],
#  [483, 'Skärvångens kyrkogård'],
#  [484, 'Hotagens kyrkogård'],
#  [485, 'Laxsjö kyrkogård'],
#  [486, 'Fors kyrkogård'],
#  [487, 'Frösö kyrkogård'],
#  [488, 'Frösö Västra kyrkogård'],
#  [489, 'Norderö kyrkogård'],
#  [490, 'Sunne kyrkogård'],
#  [491, 'Ankarede kyrkogård'],
#  [492, 'Frostvikens kyrkogård'],
#  [493, 'Gäddede kyrkogård'],
#  [494, 'Vikens kapellkyrkogård'],
#  [495, 'Häggenås kyrkogård'],
#  [496, 'Kyrkås kyrkogård'],
#  [497, 'Lits kyrkogård'],
#  [498, 'Håsjö kyrkogård'],
#  [499, 'Hällesjö kyrkogård'],
#  [500, 'Hede kyrkogård'],
#  [501, 'Ljungdalens skogskyrkogård'],
#  [502, 'Hoppsan! Sidan kunde inte hittas'],
#  [503, 'Storsjö skogskyrkogård'],
#  [504, 'Vemdalens kyrkogård'],
#  [505, 'Vemhåns begravningsplats'],
#  [506, 'Alsens kyrkogård'],
#  [507, 'Offerdals kyrkogård'],
#  [508, 'Rönnöfors kyrkogård'],
#  [509, 'Norra begravningsplatsen'],
#  [510, 'Östra begravningsplatsen'],
#  [511, 'Köttsjöns begravningsplats'],
#  [512, 'Ragunda kyrkogård'],
#  [513, 'Hoppsan! Sidan kunde inte hittas'],
#  [514, 'Revsunds kyrkogård'],
#  [515, 'Sundsjö gamla kyrkogård'],
#  [516, 'Aspås kyrkogård'],
#  [517, 'Näskotts kyrkogård'],
#  [518, 'Rödöns kyrkogård'],
#  [519, 'Ås kyrkogård'],
#  [520, 'Bergs kyrkogård'],
#  [521, 'Gillhovs kyrkogård'],
#  [522, 'Hackås kyrkogård'],
#  [523, 'Klövsjö kyrkogård'],
#  [524, 'Myssjö kyrkogård'],
#  [525, 'Ovikens kyrkogård'],
#  [526, 'Rätans kyrkogård'],
#  [527, 'Åsarne kyrkogård'],
#  [528, 'Alanäs kyrkogård'],
#  [529, 'Bodums kyrkogård'],
#  [530, 'Fjällsjö kyrkogård'],
#  [531, 'Gåxsjö kyrkogård'],
#  [532, 'Hammerdals kyrkogård'],
#  [533, 'Rotnäsets begravningsplats'],
#  [534, 'Ströms gamla kyrkogård'],
#  [535, 'Ströms nya kyrkogård'],
#  [536, 'Strömsunds skogskyrkogård'],
#  [537, 'Hoppsan! Sidan kunde inte hittas'],
#  [538, 'Tåsjö kyrkogård'],
#  [539, 'Lillhärdals kyrkogård'],
#  [540, 'Linsells kyrkogård'],
#  [541, 'Svegs kyrkogård'],
#  [542, 'Älvros kyrkogård'],
#  [543, 'Bruksvallarnas kyrkogård'],
#  [544, 'Ljusnedals gamla kyrkogård'],
#  [545, 'Ljusnedals nya kyrkogård'],
#  [546, 'Tännäs kyrkogård'],
#  [547, 'Hållans kyrkogård'],
#  [548, 'Högvålens kyrkogård'],
#  [549, 'Kalls kyrkogård'],
#  [550, 'Undersåkers kyrkogård'],
#  [551, 'Hallens gamla kyrkogård'],
#  [552, 'Hoppsan! Sidan kunde inte hittas'],
#  [553, 'Hallens nya kyrkogård'],
#  [554, 'Hallens västra kyrkogård'],
#  [555, 'Marby kyrkogård'],
#  [556, 'Mattmars kyrkogård'],
#  [557, 'Mörsils västra kyrkogård'],
#  [558, 'Mörsils östra kyrkogård'],
#  [559, 'Ytterhogdals kyrkogård'],
#  [560, 'Ängersjö kyrkogård'],
#  [561, 'Överhogdals kyrkogård'],
#  [562, 'Svarttorps gamla kyrkogård'],
#  [563, 'Alseda kyrkogård'],
#  [564, 'Karlstorps kyrkogård'],
#  [565, 'Skede kyrkogård'],
#  [566, 'Skirö kyrkogård'],
#  [567, 'Ökna kyrkogård'],
#  [568, 'Anderstorps gamla kyrkogård'],
#  [569, 'Anderstorps nya kyrkogård'],
#  [570, 'Askeryds kyrkogård'],
#  [571, 'Aneby kyrkogård'],
#  [572, 'Bredestads kyrkogård'],
#  [573, 'Bälaryds kyrkogård'],
#  [574, 'Frinnaryds kyrkogård'],
#  [575, 'Haurida kyrkogård'],
#  [576, 'Lommaryds kyrkogård'],
#  [577, 'Marbäcks kyrkogård'],
#  [578, 'Vireda kyrkogård'],
#  [579, 'Bäckseda kyrkogård'],
#  [580, 'Korsberga kyrkogård'],
#  [581, 'Lemnhults kyrkogård'],
#  [582, 'Nye kyrkogård'],
#  [583, 'Näshults kyrkogård'],
#  [584, 'Stenberga kyrkogård'],
#  [585, 'Södra Solberga kyrkogård'],
#  [586, 'Bankeryds kyrkogård'],
#  [587, 'Barkeryds gamla kyrkogård'],
#  [588, 'Forserums kyrkogård'],
#  [589, 'Barnarps kyrkogård'],
#  [590, 'Ödestugu kyrkogård'],
#  [591, 'Bredaryds kyrkogård'],
#  [592, 'Kulltorps kyrkogård'],
#  [593, 'Burseryds kyrkogård'],
#  [594, 'Sandviks kyrkogård'],
#  [595, 'Södra Hestra kyrkogård'],
#  [596, 'Gryteryds kyrkogård'],
#  [597, 'Bondstorps kyrkogård'],
#  [598, 'Byarums kyrkogård'],
#  [599, 'Svenarums kyrkogård'],
#  [600, 'Hoppsan! Sidan kunde inte hittas'],
#  [601, 'Eksjö S:t Lars kyrkogård'],
#  [602, 'Hoppsan! Sidan kunde inte hittas'],
#  [603, 'Eksjö skogskyrkogård'],
#  [604, 'Dannäs kyrkogård'],
#  [605, 'Forsheda kyrkogård'],
#  [606, 'Hångers gamla kyrkogård'],
#  [607, 'Hångers nya kyrkogård'],
#  [608, 'Kärda kyrkogård'],
#  [609, 'Torskinge kyrkogård'],
#  [610, 'Gyllenfors kyrkogård'],
#  [611, 'Bosebo kyrkogård'],
#  [612, 'Båraryds kyrkogård'],
#  [613, 'Gislaveds kyrkogård'],
#  [614, 'Gislaveds södra griftegård'],
#  [615, 'Våthults kyrkogård'],
#  [616, 'Gnosjö kyrkogård'],
#  [617, 'Hoppsan! Sidan kunde inte hittas'],
#  [618, 'Gränna kyrkogård'],
#  [619, 'Brahekyrkans kyrkogård'],
#  [620, 'Kumlaby kyrkogård'],
#  [621, 'Brandstorps gamla kyrkogård'],
#  [622, 'Hoppsan! Sidan kunde inte hittas'],
#  [623, 'Brandstorps nya kyrkogård'],
#  [624, 'Gustav Adolfs kyrkogård'],
#  [625, 'Fiskebäcks kyrkogård'],
#  [626, 'Habo mellersta kyrkogård'],
#  [627, 'Hoppsan! Sidan kunde inte hittas'],
#  [628, 'Habo västra kyrkogård'],
#  [629, 'Habo östra kyrkogård'],
#  [630, 'Bellö kyrkogård'],
#  [631, 'Hässleby kyrkogård'],
#  [632, 'Ingatorps kyrkogård'],
#  [633, 'Kråkshults kyrkogård'],
#  [634, 'Hakarps kyrkogård'],
#  [635, 'Bråneryds kyrkogård'],
#  [636, 'Huskvarna kyrkogård'],
#  [637, 'Dunkehalla kyrkogård'],
#  [638, 'Jönköping, Slottskyrkogården'],
#  [639, 'Jönköpings skogskyrkogård'],
#  [640, 'Jönköpings östra kyrkogård'],
#  [641, 'Järstorps kyrkogård'],
#  [642, 'Ljungarums kyrkogård'],
#  [643, 'Källeryds kyrkogård'],
#  [644, 'Kävsjö kyrkogård'],
#  [645, 'Hoppsan! Sidan kunde inte hittas'],
#  [646, 'Åsenhöga kyrkogård'],
#  [647, 'Bäckaby kyrkogård'],
#  [648, 'Fröderyds kyrkogård'],
#  [649, 'Lannaskede gamla kyrkogård'],
#  [650, 'Hoppsan! Sidan kunde inte hittas'],
#  [651, 'Myresjö gamla kyrkogård'],
#  [652, 'Ramkvilla kyrkogård'],
#  [653, 'Järsnäs kyrkogård'],
#  [654, 'Lekeryds kyrkogård'],
#  [655, 'Svarttorps kyrkogård'],
#  [656, 'Månsarps kyrkogård'],
#  [657, 'Bjurbäcks kyrkogård'],
#  [658, 'Nykyrka kyrkogård'],
#  [659, 'Sandhems kyrkogård'],
#  [660, 'Utvängstorps kyrkogård'],
#  [661, 'Nässjö gamla kyrkogård'],
#  [662, 'Nässjö skogskyrkogård'],
#  [663, 'Nässjö, Anneforskyrkogården'],
#  [664, 'Norrahammars kyrkogård'],
#  [665, 'Sandseryds kyrkogård'],
#  [666, 'Norra Hestra kyrkogård'],
#  [667, 'Stengårdshult kyrkogård'],
#  [668, 'Valdshults kyrkogård'],
#  [669, 'Öreryds kyrkogård'],
#  [670, 'Angerdshestra kyrkogård'],
#  [671, 'Bottnaryds kyrkogård'],
#  [672, 'Mulseryds kyrkogård'],
#  [673, 'Norra Unnaryds kyrkogård'],
#  [674, 'Almesåkra kyrkogård'],
#  [675, 'Bodafors kyrkogård'],
#  [676, 'Bringetofta kyrkogård'],
#  [677, 'Bringetofta nya kyrkogård'],
#  [678, 'Malmbäcks gamla kyrkogård'],
#  [679, 'Malmbäcks nya kyrkogård'],
#  [680, 'Norra Sandsjö kyrkogård'],
#  [681, 'Kållerstads kyrkogård'],
#  [682, 'Reftele kyrkogård'],
#  [683, 'Ås kyrkogård'],
#  [684, 'Rogberga kyrkogård'],
#  [685, 'Öggestorps kyrkogård'],
#  [686, 'Rydaholms gamla kyrkogård'],
#  [687, 'Rydaholms nya kyrkogård'],
#  [688, 'Rydaholms östra kyrkogård'],
#  [689, 'Hjälmseryds kyrkogård'],
#  [690, 'Hjärtlanda kyrkogård'],
#  [691, 'Hultsjö kyrkogård'],
#  [692, 'Hylletofta kyrkogård'],
#  [693, 'Skepperstads kyrkogård'],
#  [694, 'Stockaryds kyrkogård'],
#  [695, 'Hoppsan! Sidan kunde inte hittas'],
#  [696, 'Vallsjö kyrkogård'],
#  [697, 'Vrigstads kyrkogård'],
#  [698, 'Skärstads kyrkogård'],
#  [699, 'Ölmstads kyrkogård'],
#  [700, 'Edshults kyrkogård'],
#  [701, 'Hults kyrkogård'],
#  [702, 'Höreda kyrkogård'],
#  [703, 'Mellby kyrkogård'],
#  [704, 'Flisby kyrkogård'],
#  [705, 'Norra Solberga kyrkogård'],
#  [706, 'Hagshults kyrkogård'],
#  [707, 'Skillingaryds skogskyrkogård'],
#  [708, 'Tofteryds kyrkogård'],
#  [709, 'Åkers kyrkogård'],
#  [710, 'Adelövs kyrkogård'],
#  [711, 'Linderås kyrkogård'],
#  [712, 'Sommens skogskyrkogård'],
#  [713, 'Säby kyrkogård'],
#  [714, 'Tranås gamla griftegård'],
#  [715, 'Tranås nya griftegård'],
#  [716, 'Fryele kyrkogård'],
#  [717, 'Nydala kyrkogård'],
#  [718, 'Hoppsan! Sidan kunde inte hittas'],
#  [719, 'Värnamo norra kyrkogård'],
#  [720, 'Värnamo södra kyrkogård'],
#  [721, 'Björkö kyrkogård'],
#  [722, 'Näsby kyrkogård'],
#  [723, 'Nävelsjö kyrkogård'],
#  [724, 'Vetlanda gamla kyrkogård'],
#  [725, 'Vetlanda parkkyrkogård'],
#  [726, 'Vetlanda skogskyrkogård'],
#  [727, 'Vetlanda, Kapellkyrkogården'],
#  [728, 'Smålandsstenars kyrkogård'],
#  [729, 'Villstads gamla kyrkogård'],
#  [730, 'Villstads nya kyrkogård'],
#  [731, 'Gällaryds kyrkogård'],
#  [732, 'Tånnö kyrkogård'],
#  [733, 'Voxtorps kyrkogård'],
#  [734, 'Ålems kyrkogård'],
#  [735, 'Hoppsan! Sidan kunde inte hittas'],
#  [736, 'Bockara kyrkogård'],
#  [737, 'Döderhults kyrkogård'],
#  [738, 'Kristdala norra kyrkogård'],
#  [739, 'Kristdala södra kyrkogård'],
#  [740, 'Påskallaviks kyrkogård'],
#  [741, 'Dörby gamla kyrkogård'],
#  [742, 'Dörby nya kyrkogård'],
#  [743, 'Hossmo gamla kyrkogård'],
#  [744, 'Hossmo kyrkogårds urnlund'],
#  [745, 'Hossmo nya kyrkogård'],
#  [746, 'Hossmo södra kyrkogård'],
#  [747, 'Algutsboda kyrkogård'],
#  [748, 'Emmaboda kyrkogård'],
#  [749, 'Långasjö kyrkogård'],
#  [750, 'Vissefjärda kyrkogård'],
#  [751, 'Förlösa kyrkogård'],
#  [752, 'Kläckeberga kyrkogård'],
#  [753, 'Gladhammars kyrkogård'],
#  [754, 'Törnsfalls kyrkogård'],
#  [755, 'Västrums kyrkogård'],
#  [756, 'Hjorteds kyrkogård'],
#  [757, 'Fagerhults kyrkogård'],
#  [758, 'Fågelfors kyrkogård'],
#  [759, 'Högsby kyrkogård'],
#  [760, 'Långemåla kyrkogård'],
#  [761, 'Hultsfreds kyrkogård'],
#  [762, 'Lönneberga kyrkogård'],
#  [763, 'Vena kyrkogård'],
#  [764, 'Kalmar mosaiska kyrkogård (Småland)'],
#  [765, 'Kalmar muslimska begravningsplats (Småland)'],
#  [766, 'Kalmar norra kyrkogård'],
#  [767, 'Kalmar skogskyrkogård'],
#  [768, 'Kalmar södra kyrkogård'],
#  [769, 'Arby kyrkogård'],
#  [770, 'Hagby kyrkogård'],
#  [771, 'Halltorps kyrkogård'],
#  [772, 'Voxtorps kyrkogård'],
#  [773, 'Gårdveda kyrkogård'],
#  [774, 'Målilla kyrkogård'],
#  [775, 'Misterhults kyrkogård'],
#  [776, 'Fliseryds kyrkogård'],
#  [777, 'Mönsterås gamla kyrkogård'],
#  [778, 'Mönsterås skogskyrkogård'],
#  [779, 'Mörlunda kyrkogård'],
#  [780, 'Tveta kyrkogård'],
#  [781, 'Köpings kyrkogård'],
#  [782, 'Alböke kyrkogård'],
#  [783, 'Borgholms kyrkogård'],
#  [784, 'Bredsätra kyrkogård'],
#  [785, 'Böda kyrkogård'],
#  [786, 'Egby kyrkogård'],
#  [787, 'Föra kyrkogård'],
#  [788, 'Gärdslösa kyrkogård'],
#  [789, 'Högby kyrkogård'],
#  [790, 'Högsrums kyrkogård'],
#  [791, 'Källa kyrkogård'],
#  [792, 'Långlöts kyrkogård'],
#  [793, 'Löts kyrkogård'],
#  [794, 'Persnäs kyrkogård'],
#  [795, 'Runstens kyrkogård'],
#  [796, 'Räpplinge kyrkogård'],
#  [797, 'Dalhems kyrkogård'],
#  [798, 'Gamleby kyrkogård'],
#  [799, 'Lofta kyrkogård'],
#  [800, 'Loftahammars kyrkogård'],
#  [801, 'Odensvi kyrkogård'],
#  [802, 'Ukna kyrkogård'],
#  [803, 'Västra Eds gamla kyrkogård'],
#  [804, 'Västra Eds nya kyrkogård'],
#  [805, 'Överums kyrkogård'],
#  [806, 'Bäckebo kyrkogård'],
#  [807, 'Hälleberga kyrkogård'],
#  [808, 'Kristvalla kyrkogård'],
#  [809, 'Kråksmåla kyrkogård'],
#  [810, 'Madesjö kyrkogård'],
#  [811, 'Nybro kyrkogård'],
#  [812, 'Hoppsan! Sidan kunde inte hittas'],
#  [813, 'Nybro S:t Sigfrids kyrkogård'],
#  [814, 'Oskars kyrkogård'],
#  [815, 'Örsjö kyrkogård'],
#  [816, 'Oskarshamns gamla kyrkogård'],
#  [817, 'Oskarshamns västra begravningsplats'],
#  [818, 'Ryssby kyrkogård'],
#  [819, 'Hoppsan! Sidan kunde inte hittas'],
#  [820, 'Åby kyrkogård'],
#  [821, 'Söderåkra kyrkogård'],
#  [822, 'Karlslunda kyrkogård'],
#  [823, 'Ljungby kyrkogård'],
#  [824, 'Mortorps kyrkogård'],
#  [825, 'Djursdala kyrkogård'],
#  [826, 'Södra Vi kyrkogård'],
#  [827, 'Algutsrums kyrkogård'],
#  [828, 'Glömminge kyrkogård'],
#  [829, 'Gräsgårds kyrkogård'],
#  [830, 'Gårdby kyrkogård'],
#  [831, 'Hulterstads kyrkogård'],
#  [832, 'Kastlösa kyrkogård'],
#  [833, 'Mörbylånga kyrkogård'],
#  [834, 'Norra Möckleby kyrkogård'],
#  [835, 'Resmo kyrkogård'],
#  [836, 'Sandby kyrkogård'],
#  [837, 'Segerstads kyrkogård'],
#  [838, 'Smedby kyrkogård'],
#  [839, 'Stenåsa kyrkogård'],
#  [840, 'Södra Möckleby kyrkogård'],
#  [841, 'Torslunda kyrkogård'],
#  [842, 'Ventlinge kyrkogård'],
#  [843, 'Vickleby kyrkogård'],
#  [844, 'Ås kyrkogård'],
#  [845, 'Ankarsrums kyrkogård'],
#  [846, 'Blackstads kyrkogård'],
#  [847, 'Hallingebergs gravkapell'],
#  [848, 'Hallingebergs kyrkogård'],
#  [849, 'Hoppsan! Sidan kunde inte hittas'],
#  [850, 'Gullabo kyrkogård'],
#  [851, 'Torsås kyrkogård'],
#  [852, 'Västerviks gamla kyrkogård'],
#  [853, 'Västerviks nya kyrkogård'],
#  [854, 'Vimmerby kyrkogård'],
#  [855, 'Frödinge kyrkogård'],
#  [856, 'Locknevi kyrkogård'],
#  [857, 'Pelarne kyrkogård'],
#  [858, 'Rumskulla kyrkogård'],
#  [859, 'Tuna kyrkogård'],
#  [860, 'Järeda kyrkogård'],
#  [861, 'Virserums kyrkogård'],
#  [862, 'Älghults gamla kyrkogård'],
#  [863, 'Älghults kapellkyrkogård'],
#  [864, 'Hoppsan! Sidan kunde inte hittas'],
#  [865, 'Älghults nya kyrkogård'],
#  [866, 'Älghults stora kyrkogård'],
#  [867, 'Älmhults kyrkogård'],
#  [868, 'Alvesta gamla kyrkogård'],
#  [869, 'Alvesta kyrkogård'],
#  [870, 'Alvesta skogskyrkogård'],
#  [871, 'Hjortsberga kyrkogård'],
#  [872, 'Härlövs kyrkogård'],
#  [873, 'Kvenneberga kyrkogård'],
#  [874, 'Lekaryds kyrkogård'],
#  [875, 'Granhults kyrkogård'],
#  [876, 'Nottebäcks kyrkogård'],
#  [877, 'Åseda gamla kyrkogård'],
#  [878, 'Åseda skogskyrkogård'],
#  [879, 'Berga kyrkogård'],
#  [880, 'Bolmsö kyrkogård'],
#  [881, 'Dörarps kyrkogård'],
#  [882, 'Tannåkers kyrkogård'],
#  [883, 'Vittaryds kyrkogård'],
#  [884, 'Göteryds kyrkogård'],
#  [885, 'Hallaryds kyrkogård'],
#  [886, 'Pjätteryds kyrkogård'],
#  [887, 'Herråkra kyrkogård'],
#  [888, 'Lenhovda kyrkogård'],
#  [889, 'Ekeberga kyrkogård'],
#  [890, 'Hovmantorps kyrkogård'],
#  [891, 'Lessebo kyrkogård'],
#  [892, 'Ljuders kyrkogård'],
#  [893, 'Angelstads kyrkogård'],
#  [894, 'Annerstads kyrkogård'],
#  [895, 'Lidhults kyrkogård'],
#  [896, 'Ljungby gamla kyrkogård'],
#  [897, 'Ljungby skogskyrkogård'],
#  [898, 'Odensjö kyrkogård'],
#  [899, 'Torpa kyrkogård'],
#  [900, 'Vrå kyrkogård'],
#  [901, 'Markaryds kyrkogård'],
#  [902, 'Mistelås kyrkogård'],
#  [903, 'Moheda kyrkogård'],
#  [904, 'Slätthögs kyrkogård'],
#  [905, 'Jäts gamla kyrkogård'],
#  [906, 'Jäts nya kyrkogård'],
#  [907, 'Nöbbele kyrkogård'],
#  [908, 'Uråsa kyrkogård'],
#  [909, 'Östra Torsås kyrkogård'],
#  [910, 'Agunnaryds kyrkogård'],
#  [911, 'Ryssby kyrkogård'],
#  [912, 'Tutaryds kyrkogård'],
#  [913, 'Drevs gamla kyrkogård'],
#  [914, 'Drevs nya kyrkogård'],
#  [915, 'Dädesjö kyrkogård'],
#  [916, 'Hornaryds kyrkogård'],
#  [917, 'Sjösås gamla kyrkogård'],
#  [918, 'Sjösås nya kyrkogård'],
#  [919, 'Skatelövs kyrkogård'],
#  [920, 'Västra Torsås kyrkogård'],
#  [921, 'Hamneda kyrkogård'],
#  [922, 'Kånna kyrkogård'],
#  [923, 'Nöttja kyrkogård'],
#  [924, 'Södra Ljunga kyrkogård'],
#  [925, 'Gårdsby kyrkogård'],
#  [926, 'Söraby kyrkogård'],
#  [927, 'Tjureda kyrkogård'],
#  [928, 'Tolgs kyrkogård'],
#  [929, 'Stenbrohults kyrkogård'],
#  [930, 'Almundsryds kyrkogård'],
#  [931, 'Almundsryds nya östra kyrkogård'],
#  [932, 'Linneryds kyrkogård'],
#  [933, 'Södra Sandsjö kyrkogård'],
#  [934, 'Ebbalycke begravningsplats'],
#  [935, 'Tingsås kyrkogård'],
#  [936, 'Urshults kyrkogård'],
#  [937, 'Väckelsångs kyrkogård'],
#  [938, 'Älmeboda kyrkogård'],
#  [939, 'Hinneryds kyrkogård'],
#  [940, 'Traryd Eklunden'],
#  [941, 'Traryds gamla kyrkogård'],
#  [942, 'Traryds mellersta kyrkogård'],
#  [943, 'Hoppsan! Sidan kunde inte hittas'],
#  [944, 'Traryds norra kyrkogård'],
#  [945, 'Traryds Skanskyrkogård'],
#  [946, 'Hoppsan! Sidan kunde inte hittas'],
#  [947, 'Traryds västra kyrkogård'],
#  [948, 'Tegnérkyrkogården'],
#  [949, 'Aneboda kyrkogård'],
#  [950, 'Asa kyrkogård'],
#  [951, 'Bergs kyrkogård'],
#  [952, 'Bergunda kyrkogård'],
#  [953, 'Dänningelanda kyrkogård'],
#  [954, 'Furuby kyrkogård'],
#  [955, 'Hemmesjö kyrkogård'],
#  [956, 'Kalvsviks kyrkogård'],
#  [957, 'Ormesberga kyrkogård'],
#  [958, 'Tegnaby kyrkplats'],
#  [959, 'Tävelsås kyrkogård'],
#  [960, 'Vederslövs kyrkogård'],
#  [961, 'Hovshaga kyrkogård'],
#  [962, 'Skogslyckans kyrkogård'],
#  [963, 'Hoppsan! Sidan kunde inte hittas'],
#  [964, 'Öja kyrkogård'],
#  [965, 'Öjaby kyrkogård'],
#  [966, 'Örs kyrkogård'],
#  [967, 'Härlunda kyrkogård'],
#  [968, 'Virestads kyrkogård'],
#  [969, 'Blädinge kyrkogård'],
#  [970, 'Vislanda kyrkogård'],
#  [971, 'Älvsby gamla kyrkogård'],
#  [972, 'Hoppsan! Sidan kunde inte hittas'],
#  [973, 'Älvsby nya kyrkogård'],
#  [974, 'Älvsby skogskyrkogård'],
#  [975, 'Arvidsjaurs kyrkogård'],
#  [976, 'Glommersträsks kyrkogård'],
#  [977, 'Moskosels kyrkogård'],
#  [978, 'Edefors gamla kyrkogård'],
#  [979, 'Hoppsan! Sidan kunde inte hittas'],
#  [980, 'Edefors nya kyrkogård'],
#  [981, 'Edefors skogskyrkogård'],
#  [982, 'Gällivare kyrkogård'],
#  [983, 'Hakkas kyrkogård'],
#  [984, 'Malmbergets kyrkogård'],
#  [985, 'Nattavaara kyrkogård'],
#  [986, 'Nilivaara kyrkogård'],
#  [987, 'Hoppsan! Sidan kunde inte hittas'],
#  [988, 'Haparanda gamla kyrkogård'],
#  [989, 'Hoppsan! Sidan kunde inte hittas'],
#  [990, 'Haparanda nya kyrkogård'],
#  [991, 'Karungi gamla kyrkogård'],
#  [992, 'Hoppsan! Sidan kunde inte hittas'],
#  [993, 'Karungi nya kyrkogård'],
#  [994, 'Lappträsks kyrkogård'],
#  [995, 'Seskarö kyrkogård'],
#  [996, 'Hortlax kyrkogård'],
#  [997, 'Hortlax skogskyrkogård'],
#  [998, 'Piteå kyrkogård'],
#  [999, 'Gråträsks kyrkogård'],
#  [1000, 'Hedens begravningsplats'],
#  ...]

# %%
end = datetime.now()
print("Ended: ", end)
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2022-11-13 14:47:29.335502
# Time elapsed (hh:mm:ss.ms) 1:05:24.239783
